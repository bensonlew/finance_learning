# %%
import akshare as ak

# 使用akshare获取股指期货历史数据
#df = ak.stock_zh_index_daily(symbol="sh000001", start_date="20220101", end_date="20220201")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import akshare as ak
#       3 # 使用akshare获取股指期货历史数据
# ----> 4 df = ak.stock_zh_index_daily(symbol="sh000001", start_date="20220101", end_date="20220201")
#
# TypeError: stock_zh_index_daily() got an unexpected keyword argument 'start_date'

# %%
import time
import akshare as ak

cffex_text = ak.match_main_contract(symbol="cffex")

while True:
    time.sleep(3)
    futures_zh_spot_df = ak.futures_zh_spot(symbol=cffex_text, market="FF", adjust='0')
    print(futures_zh_spot_df)
# Out:
# IF2402
# TF2403
# sngz_qh 无主力合约
# IH2402
# IC2402
# TS2403
# IM2402
# cffex主力合约获取成功
#            symbol      time      open      high       low  current_price  \
# 0   沪深300指数期货2402  15:00:00  3147.400  3218.000  3091.200       3171.200
# 1     5年期国债期货2403  15:15:00   102.935   102.945   102.780        102.855
# 2    上证50指数期货2402  15:00:00  2208.800  2265.800  2192.600       2240.000
# 3   中证500指数期货2402  15:00:00  4475.000  4585.000  4208.400       4380.000
# 4     2年期国债期货2403  15:15:00   101.350   101.372   101.294        101.322
# 5  中证1000指数期货2402  15:00:00  4453.000  4458.600  4081.200       4176.600
#
#       hold  volume        amount
# 0  65176.0   91838  2.900605e+08
# 1  93135.0   37075  3.813139e+06
# 2  36691.0   49277  1.099696e+08
# 3  68243.0  105377  4.624405e+08
# 4  59989.0   21933  2.222456e+06
# 5  81624.0  161837  6.914358e+08
#            symbol      time      open      high       low  current_price  \
# ...

# %%
get_futures_daily_df = ak.get_futures_daily(start_date="20230701", end_date="20231216", market="DCE")
print(get_futures_daily_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '商品名称'
#
# The above exception was the direct cause of the following exception:
# ...

# %%
futures_zh_daily_sina_df = ak.futures_zh_daily_sina(symbol="V2306")

# %%
futures_zh_daily_sina_df
# Out:
#            date    open    high     low   close  volume  hold  settle
# 0    2022-06-16  7939.0  7939.0  7908.0  7908.0       4     4  7925.0
# 1    2022-06-17  7888.0  7888.0  7788.0  7849.0       7    10  7834.0
# 2    2022-06-20  7688.0  7724.0  7654.0  7654.0       6    15  7691.0
# 3    2022-06-21  7588.0  7588.0  7516.0  7552.0      19    20  7549.0
# 4    2022-06-22  7515.0  7515.0  7282.0  7282.0       9    22  7408.0
# ..          ...     ...     ...     ...     ...     ...   ...     ...
# 232  2023-06-08  5569.0  5569.0  5569.0  5569.0      31  4849  5561.0
# 233  2023-06-09  5580.0  5601.0  5562.0  5601.0     134  4853  5570.0
# 234  2023-06-12  5601.0  5601.0  5601.0  5601.0      35  4857  5570.0
# 235  2023-06-13  5562.0  5580.0  5505.0  5580.0      27  4863  5546.0
# 236  2023-06-14  5580.0  5580.0  5580.0  5580.0     147     0  5636.0
#
# [237 rows x 8 columns]

# %%
# ICM1

# %%
futures_zh_daily_sina_df = ak.futures_zh_daily_sina(symbol="ICM1")
print(get_futures_daily_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 futures_zh_daily_sina_df = ak.futures_zh_daily_sina(symbol="ICM1")
#       2 print(get_futures_daily_df)
#
# File /liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/akshare/futures/futures_zh_sina.py:665, in futures_zh_daily_sina(symbol)
#     663 r = requests.get(url, params=params)
#     664 temp_df = pd.DataFrame(json.loads(r.text.split("=(")[1].split(");")[0]))
# --> 665 temp_df.columns = [
#     666     "date",
#     667     "open",
#     668     "high",
#     669     "low",
#     670     "close",
#     671     "volume",
#     672     "hold",
#     673     "settle",
#     674 ]
#     675 temp_df["open"] = pd.to_numeric(temp_df["open"])
#     676 temp_df["high"] = pd.to_numeric(temp_df["high"])
#
# ...
