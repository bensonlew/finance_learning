# %%
import numpy as np
from scipy.stats import pearsonr
from sklearn.neighbors import BallTree

# 生成时间序列数据
np.random.seed(0)
X = np.random.randn(100000, 20)
y = np.random.randn(20)

# 计算pearson相关系数矩阵
corr_matrix = np.zeros((X.shape[0],))
for i in range(X.shape[0]):
    corr, _ = pearsonr(X[i], y)
    corr_matrix[i] = corr

# 构建ball tree
tree = BallTree(X, metric='euclidean')

# %%
# 查询相似的时间序列
k = 5  # 返回5个最相似的时间序列
distances, indices = tree.query(y.reshape(1, -1), k=k, return_distance=True)

# 打印结果
print("相似度最高的{}个序列：".format(k))
for i in range(k):
    idx = indices[0][i]
    corr = corr_matrix[idx]
    print("序列{}，pearson相关系数为{}，欧氏距离为{}".format(idx, corr, distances[0][i]))
# Out:
# 相似度最高的5个序列：
# 序列21380，pearson相关系数为0.7153313588959008，欧氏距离为2.8319087341686444
# 序列63124，pearson相关系数为0.7345123265226512，欧氏距离为2.8538328229663183
# 序列75469，pearson相关系数为0.7117811811682344，欧氏距离为2.8609330662226364
# 序列42154，pearson相关系数为0.717717381060927，欧氏距离为3.0341871779769183
# 序列22683，pearson相关系数为0.683495183014961，欧氏距离为3.0910342381034983

# %%
def ball_tree(X, y):
    # 计算pearson相关系数矩阵
    corr_matrix = np.zeros((X.shape[0],))
    for i in range(X.shape[0]):
        corr, _ = pearsonr(X[i], y)
        corr_matrix[i] = corr

    # 构建ball tree
    tree = BallTree(X, metric='euclidean')
    return corr_matrix, tree

# %%
def normal_by_row(data):

    # 计算每列的均值和标准差
    mean = np.mean(data, axis=1, keepdims=True)
    std = np.std(data, axis=1, keepdims=True)

    # 标准化数据
    data_standardized = (data - mean) / std
    return data_standardized

# %%
x_train = np.load("sh510050_train.npy")

# %%
x_train_normal = normal_by_row(x_train)

# %%
x_test = np.load("sh510050_test.npy")
x_test_normal = normal_by_row(x_test)

# %%
cor_mat, tree = ball_tree(x_train, x_test[1000])

# %%
len(cor_mat[cor_mat>0.85])
# Out:
# 0

# %%
for xt in x_test[1000:]:
    cor_mat, tree = ball_tree(x_train, xt)
    print(len(cor_mat[cor_mat>0.85]) )
# Out:
# 0
# 0
# 3
# 6
# 7
# 8
# 9
# 10
# 11
# 11
# 12
# 13
# 14
# 15
# 16
# 18
# 19
# 20
# 26
# 29
# 31
# 33
# 33
# 34
# 34
# 34
# 34
# 35
# 35
# 35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_287636/1938657090.py in <module>
#       1 for xt in x_test[1000:]:
# ----> 2     cor_mat, tree = ball_tree(x_train, xt)
#       3     print(len(cor_mat[cor_mat>0.85]) )
#
# /tmp/ipykernel_287636/4186712346.py in ball_tree(X, y)
#       7
#       8     # 构建ball tree
# ----> 9     tree = BallTree(X, metric='euclidean')
#      10     return corr_matrix, tree
#
# KeyboardInterrupt:

# %%
k = 50  # 返回5个最相似的时间序列
distances, indices = tree.query(x_test[1000].reshape(1, -1), k=k, return_distance=True)

# 打印结果
print("相似度最高的{}个序列：".format(k))
for i in range(k):
    idx = indices[0][i]
    corr = corr_matrix[idx]
    print("序列{}，pearson相关系数为{}，欧氏距离为{}".format(idx, corr, distances[0][i]))
# Out:
# 相似度最高的50个序列：
# 序列18151，pearson相关系数为-0.12683094472925563，欧氏距离为0.8126971145512951
# 序列18152，pearson相关系数为0.1018752286736739，欧氏距离为0.8127115847580865
# 序列18150，pearson相关系数为0.18122574946656028，欧氏距离为0.8132695494115104
# 序列18153，pearson相关系数为-0.212663581968511，欧氏距离为0.8134253991608582
# 序列18154，pearson相关系数为-0.3648515766318374，欧氏距离为0.814441428219366
# 序列18149，pearson相关系数为0.26421210310802595，欧氏距离为0.8146611074551192
# 序列18155，pearson相关系数为-0.007955179394242198，欧氏距离为0.8161035473516832
# 序列18148，pearson相关系数为0.10006624443073732，欧氏距离为0.8163975502168052
# 序列18156，pearson相关系数为0.06290927586801941，欧氏距离为0.8178740000758069
# 序列18147，pearson相关系数为-0.14263921580226804，欧氏距离为0.8187453083835056
# 序列18157，pearson相关系数为0.019447762145249403，欧氏距离为0.8197299311358596
# 序列18158，pearson相关系数为0.07025435938304901，欧氏距离为0.8214900121121386
# 序列18146，pearson相关系数为-0.12626373087649567，欧氏距离为0.8215905793033419
# 序列18159，pearson相关系数为-0.09040561727255804，欧氏距离为0.8234576613281348
# 序列18145，pearson相关系数为-0.43483280023907495，欧氏距离为0.8248977876076535
# 序列18160，pearson相关系数为0.5038632129392995，欧氏距离为0.8255763077995889
# 序列18161，pearson相关系数为0.2332328528244452，欧氏距离为0.8281471125349653
# 序列18144，pearson相关系数为-0.3058397819644275，欧氏距离为0.8285201506300264
# 序列18162，pearson相关系数为0.31389072568437376，欧氏距离为0.8311556773553324
# 序列18143，pearson相关系数为0.14044691132469594，欧氏距离为0.8325705255412303
# 序列18163，pearson相关系数为0.13043524806222176，欧氏距离为0.8342825900137204
# 序列18142，pearson相关系数为-0.41689809337762024，欧氏距离为0.8369089556218177
# 序列18164，pearson相关系数为-0.2045369253759053，欧氏距离为0.8374171959065575
# 序列18165，pearson相关系数为0.21950861277104097，欧氏距离为0.8402374902371361
# 序列18141，pearson相关系数为0.16402087005604116，欧氏距离为0.841537426381027
# 序列18166，pearson相关系数为-0.04999660626852211，欧氏距离为0.8427521581105569
# 序列18167，pearson相关系数为-0.29671396346545126，欧氏距离为0.8450953792324283
# 序列18140，pearson相关系数为-0.040397287411731576，欧氏距离为0.8463641533051852
# 序列18168，pearson相关系数为-0.06697293749819702，欧氏距离为0.847587847954418
# 序列18169，pearson相关系数为-0.29210315960368227，欧氏距离为0.8505066019732016
# 序列18139，pearson相关系数为0.3232798598623387，欧氏距离为0.851418181624049
# 序列18170，pearson相关系数为0.03729579932849088，欧氏距离为0.8539812878512045
# 序列18138，pearson相关系数为-0.17935476998376085，欧氏距离为0.856701768411857
# 序列18171，pearson相关系数为-0.28335064271406446，欧氏距离为0.858173152691228
# 序列18137，pearson相关系数为0.16367807769776216，欧氏距离为0.8621432827552518
# 序列18172，pearson相关系数为-0.052787343642121086，欧氏距离为0.8628732467749837
# 序列18136，pearson相关系数为0.17209747639596704，欧氏距离为0.8676488690708939
# 序列18173，pearson相关系数为0.24541658829408908，欧氏距离为0.8679887787293111
# 序列18174，pearson相关系数为-0.002533177855442477，欧氏距离为0.8730256811801138
# 序列18135，pearson相关系数为-0.10744666434379722，欧氏距离为0.8732099403923447
# 序列18175，pearson相关系数为0.03511286547556612，欧氏距离为0.8776743131708946
# 序列18134，pearson相关系数为0.19119570612759135，欧氏距离为0.8786555183915941
# 序列18176，pearson相关系数为0.1001025814861873，欧氏距离为0.8818932361686427
# 序列18133，pearson相关系数为-0.45785570735048314，欧氏距离为0.8840096832048853
# 序列18177，pearson相关系数为-0.08230033521542506，欧氏距离为0.8857855496676391
# 序列18132，pearson相关系数为0.17121507842584752，欧氏距离为0.8892795286072886
# 序列18178，pearson相关系数为-0.29002696835050035，欧氏距离为0.8894014841453782
# 序列18179，pearson相关系数为0.2394887127939864，欧氏距离为0.8930435823631465
# 序列18131，pearson相关系数为-0.36103693128462394，欧氏距离为0.8945991728142848
# 序列18180，pearson相关系数为-0.32358224992773477，欧氏距离为0.8969754288719406

# %%
# Out:
# array([2.5682, 2.567 , 2.5656, 2.5638, 2.5632, 2.5638, 2.5638, 2.564 ,
#        2.5642, 2.564 , 2.5684, 2.5744, 2.5822, 2.59  , 2.598 , 2.6018,
#        2.6056, 2.609 , 2.6114, 2.6134, 2.6154, 2.615 , 2.6142, 2.6154,
#        2.6156, 2.6166, 2.6184, 2.6194, 2.6196, 2.6214, 2.6226, 2.6236,
#        2.6252, 2.6254, 2.6262, 2.6264, 2.6274, 2.628 , 2.6302, 2.6312,
#        2.6324, 2.6334, 2.6338, 2.6332, 2.6322, 2.6296, 2.6274, 2.6262,
#        2.6252, 2.6256, 2.6262, 2.6274, 2.628 , 2.6284, 2.6278, 2.628 ,
#        2.6268, 2.6258, 2.6244, 2.6216, 2.6172, 2.6144, 2.611 , 2.6078,
#        2.6066, 2.6078, 2.608 , 2.608 , 2.6084, 2.6084, 2.6082, 2.6082,
#        2.6092, 2.6106, 2.6114, 2.6118, 2.6122, 2.6126, 2.6124, 2.6128,
#        2.6138, 2.6144, 2.6142, 2.6158, 2.6166, 2.6174, 2.6186, 2.6198,
#        2.62  , 2.6208, 2.6212, 2.6214, 2.6224, 2.623 , 2.6228, 2.6224,
#        2.622 , 2.6216, 2.6218, 2.6218, 2.6222, 2.6226, 2.6228, 2.6228,
#        2.6234, 2.6236, 2.6258, 2.627 , 2.6274, 2.628 , 2.6278, 2.6256,
#        2.623 , 2.62  , 2.617 , 2.6152, 2.613 , 2.6126, 2.6122, 2.6124,
#        2.6112, 2.6106, 2.6098, 2.6096, 2.6096, 2.611 , 2.6122, 2.6134,
#        2.6146, 2.615 , 2.6178, 2.6198, 2.6206, 2.6214, 2.6216, 2.6182,
#        2.6152, 2.6138, 2.613 , 2.6124, 2.6128, 2.6122, 2.6106, 2.6088,
#        2.6082, 2.6072, 2.6076, 2.608 , 2.609 , 2.6092, 2.6096, 2.6098,
#        2.6098, 2.6092, 2.6076, 2.6078, 2.6064, 2.6052, 2.6036, 2.6026,
#        2.5992, 2.597 , 2.5942, 2.59  , 2.5868, 2.5848, 2.5824, 2.5806,
#        2.581 , 2.5812, 2.5806, 2.5812, 2.581 , 2.58  , 2.5788, 2.5782,
#        2.5774, 2.5762, 2.5744, 2.5728, 2.5706, 2.5686, 2.567 , 2.5662,
#        2.5652, 2.5634, 2.5626, 2.5626, 2.5634, 2.563 , 2.5636, 2.5636,
#        2.564 , 2.5636, 2.5636, 2.5632, 2.5622, 2.561 , 2.56  , 2.5598,
#        2.5596, 2.559 , 2.556 , 2.552 , 2.5502, 2.5488, 2.546 , 2.5456,
#        2.5464, 2.5446, 2.5424, 2.5432, 2.5434, 2.5436, 2.5442, 2.5444,
#        2.5438, 2.5438, 2.5432, 2.544 , 2.5446, 2.5442, 2.5432, 2.5424,
#        2.5406, 2.5392, 2.5406, 2.5448, 2.5524, 2.5578, 2.5626, 2.565 ,
#        2.5644, 2.5604, 2.5584, 2.5556, 2.5524, 2.5508, 2.5496, 2.548 ,
#        2.5476, 2.5476, 2.5466, 2.5462, 2.5446, 2.5434, 2.5426, 2.5416,
#        2.5402, 2.5408, 2.5418, 2.5426, 2.5444, 2.5454, 2.546 , 2.546 ,
#        2.546 , 2.5442, 2.5426, 2.5414, 2.541 , 2.5402, 2.5414, 2.5424,
#        2.543 , 2.543 , 2.5432, 2.5424, 2.5424, 2.543 , 2.5444, 2.5454,
#        2.5456, 2.5458, 2.5446, 2.543 , 2.5412, 2.5402, 2.5392, 2.539 ,
#        2.5384, 2.5384, 2.5364, 2.5342, 2.5318, 2.5296, 2.5264, 2.525 ,
#        2.5226, 2.5212, 2.5196, 2.52  , 2.5212, 2.5234, 2.5252, 2.5274,
#        2.528 , 2.5282, 2.5248, 2.5244, 2.5202, 2.5152, 2.5074, 2.5032,
#        2.4928, 2.4858, 2.4788, 2.4772, 2.4732, 2.4738, 2.4744, 2.4756,
#        2.4734, 2.4714, 2.4668, 2.4626, 2.4616, 2.4606, 2.462 , 2.4638,
#        2.4648, 2.4638, 2.4622, 2.4602, 2.4564, 2.454 , 2.4514, 2.451 ,
#        2.4518, 2.4536, 2.4544, 2.455 , 2.453 , 2.4496, 2.4462, 2.4418,
#        2.4366, 2.4352, 2.435 , 2.435 , 2.4354, 2.4378, 2.437 , 2.4338,
#        2.4322, 2.4334, 2.4328, 2.4298, 2.4332, 2.4368, 2.4372, 2.4378,
#        2.4402, 2.4372, 2.4324, 2.4296, 2.4284, 2.43  , 2.4314, 2.4326,
#        2.4326, 2.4312, 2.4278, 2.4256, 2.4246, 2.4256, 2.4264, 2.4302,
#        2.4364, 2.4446, 2.449 , 2.4518, 2.4526, 2.4502, 2.4468, 2.4448,
#        2.4456, 2.4458, 2.4454, 2.443 , 2.4416, 2.4402, 2.4404, 2.4406,
#        2.441 , 2.4414, 2.4398, 2.4376, 2.436 , 2.435 , 2.433 , 2.4326,
#        2.4318, 2.4312, 2.4326, 2.4358, 2.4362, 2.4382, 2.4404, 2.4406,
#        2.4426, 2.447 , 2.4486, 2.4512, 2.4538, 2.456 , 2.4578, 2.4614,
#        2.464 , 2.4674, 2.4684, 2.4688, 2.4688, 2.4678, 2.466 , 2.465 ,
#        2.4652, 2.4646, 2.4644, 2.463 , 2.4602, 2.4564, 2.453 , 2.4502,
#        2.4478, 2.4458, 2.4446, 2.4434, 2.4412, 2.439 , 2.437 , 2.4358])

# %%
X = np.random.randn(10, 20)

# %%
X[1]
# Out:
# array([ 0.32109835, -0.72023966,  0.79705145,  0.96982949, -0.05928517,
#        -0.26239031,  0.01473281,  0.01069014,  0.26606428,  0.63608734,
#        -1.77592115,  1.3669944 , -0.39379399, -0.49758993,  1.06441791,
#        -0.09557093,  0.34037208,  0.27619099, -1.71726505,  0.67911003])
