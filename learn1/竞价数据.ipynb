# %%
import akshare as ak
stock_zh_a_hist_pre_min_em_df = ak.stock_zh_a_hist_pre_min_em(symbol="515030")
print(stock_zh_a_hist_pre_min_em_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 import akshare as ak
# ----> 2 stock_zh_a_hist_pre_min_em_df = ak.stock_zh_a_hist_pre_min_em(symbol="515030")
#       3 print(stock_zh_a_hist_pre_min_em_df)
#
# File /liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/akshare/stock_feature/stock_hist_em.py:1215, in stock_zh_a_hist_pre_min_em(symbol, start_time, end_time)
#    1206 code_id_dict = code_id_map_em()
#    1207 url = "https://push2.eastmoney.com/api/qt/stock/trends2/get"
#    1208 params = {
#    1209     "fields1": "f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13",
#    1210     "fields2": "f51,f52,f53,f54,f55,f56,f57,f58",
#    1211     "ut": "fa5fd1943c7b386f172d6893dbfba10b",
#    1212     "ndays": "1",
#    1213     "iscr": "1",
#    1214     "iscca": "0",
# -> 1215     "secid": f"{code_id_dict[symbol]}.{symbol}",
# ...

# %%
stock_zh_a_hist_pre_min_em_df[:30]
# Out:
#                      时间    开盘    收盘    最高    最低  成交量  成交额   最新价
# 0   2023-07-05 09:15:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 1   2023-07-05 09:16:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 2   2023-07-05 09:17:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 3   2023-07-05 09:18:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 4   2023-07-05 09:19:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 5   2023-07-05 09:20:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 6   2023-07-05 09:21:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 7   2023-07-05 09:22:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 8   2023-07-05 09:23:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 9   2023-07-05 09:24:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 10  2023-07-05 09:25:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 11  2023-07-05 09:26:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 12  2023-07-05 09:27:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# 13  2023-07-05 09:28:00  2.71  2.71  2.71  2.71    0  0.0  2.71
# ...
