# %%
import pandas as pd
import matplotlib.pyplot as plt
import akshare as ak
import datetime

# %%
stock_zh_a_hist_163_df = ak.stock_zh_a_hist_163(symbol="sh601318", start_date="20060101", end_date="20220101")

# %%
stock_zh_a_hist_163_df
# Out:
#               日期    股票代码    名称    收盘价    最高价    最低价    开盘价    前收盘    涨跌额  \
# 0     2007-03-01  601318   N平安  46.79  50.97  45.80  50.00  33.80  12.99
# 1     2007-03-02  601318  中国平安  46.41  47.44  45.88  47.00  46.79  -0.38
# 2     2007-03-05  601318  中国平安  44.38  46.17  43.53  45.98  46.41  -2.03
# 3     2007-03-06  601318  中国平安  45.25  46.00  43.75  44.00  44.38   0.87
# 4     2007-03-07  601318  中国平安  46.48  46.90  44.91  45.29  45.25   1.23
# ...          ...     ...   ...    ...    ...    ...    ...    ...    ...
# 3609  2021-12-27  601318  中国平安  49.98  50.20  49.87  49.96  49.82   0.16
# 3610  2021-12-28  601318  中国平安  50.87  51.13  50.10  50.30  49.98   0.89
# 3611  2021-12-29  601318  中国平安  50.81  51.16  50.52  51.10  50.87  -0.06
# 3612  2021-12-30  601318  中国平安  50.41  50.99  50.41  50.90  50.81  -0.40
# 3613  2021-12-31  601318  中国平安  50.41  50.85  50.15  50.43  50.41   0.00
#
#           涨跌幅      换手率          成交量          成交金额           总市值          流通市值
# ...

# %%
stock_ipo_benefit_ths_df = ak.stock_ipo_benefit_ths()

# %%
stock_ipo_benefit_ths_df
# Out:
#       序号    股票代码  股票简称    收盘价    涨跌幅       市值  参股家数   投资总额  投资占市值比 参股对象
# 0      1  600716  凤凰股份   4.58  0.000   42.87亿     1  4.76亿   11.11   明细
# 1      2  600649  城投控股   4.11  0.489  103.97亿     1  4.67亿    4.49   明细
# 2      3  601963  重庆银行   7.75 -0.257  146.90亿     1  3.79亿    2.58   明细
# 3      4  600639  浦东金桥  11.91 -1.652  101.26亿     2  3.18亿    3.14   明细
# 4      5  000541  佛山照明   5.87 -3.135   62.12亿     1  2.93亿    4.71   明细
# ..   ...     ...   ...    ...    ...      ...   ...    ...     ...  ...
# 96    97  002574  明牌珠宝   4.74  0.424   25.03亿     1     0万    0.00   明细
# 97    98  002676  顺威股份   4.55  2.247   32.76亿     1     0万    0.00   明细
# 98    99  300500  启迪设计  18.45  0.820   32.10亿     1     0万    0.00   明细
# 99   100  600052  东望时代   5.12 -1.539   43.22亿     1     0万    0.00   明细
# 100  101  603987   康德莱  18.30 -1.454   80.81亿     1     0万    0.00   明细
#
# [101 rows x 10 columns]

# %%
stock_zh_a_stop_em_df = ak.stock_zh_a_stop_em()

# %%
stock_zh_a_stop_em_df
# Out:
#       序号      代码      名称    最新价   涨跌幅    涨跌额       成交量         成交额   振幅  \
# 0      1  400071     中弘1  0.180  5.88  0.010  246195.0  4431510.00  0.0
# 1      2  420063    武锅B3  0.115  4.55  0.005     170.0     1955.00  0.0
# 2      3  400009  广  建 1  0.700  4.48  0.030     651.0    45570.00  0.0
# 3      4  400021    华夏 3  0.770  4.05  0.030     186.0    14322.00  0.0
# 4      5  400031    鞍合成1  0.260  4.00  0.010    4125.0   107250.00  0.0
# ..   ...     ...     ...    ...   ...    ...       ...         ...  ...
# 146  147  400008   水仙Ａ 5  2.700 -4.59 -0.130      50.0    13500.00  0.0
# 147  148  400065     博元5  2.660 -4.66 -0.130    3911.0  1040326.00  0.0
# 148  149  400084    乐视网3  0.800 -4.76 -0.040   39904.0  3192320.00  0.0
# 149  150  400086     广茂1  0.170 -5.56 -0.010   32711.0   556091.76  0.0
# 150  151  400076    华信控1  0.140 -6.67 -0.010  100023.0  1400317.24  0.0
#
#         最高     最低     今开    昨收    量比   换手率    市盈率-动态     市净率
# ...

# %%
stock_zh_a_hist_163_df = ak.stock_zh_a_hist_163(symbol="sh400071", start_date="20060101", end_date="20220101")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2343815/1808022026.py in <module>
# ----> 1 stock_zh_a_hist_163_df = ak.stock_zh_a_hist_163(symbol="sh400071", start_date="20060101", end_date="20220101")
#
# /usr/local/lib/python3.8/dist-packages/akshare/stock/stock_hist_163.py in stock_zh_a_hist_163(symbol, start_date, end_date)
#      57         [item.split(",") for item in data_text.split("\r\n")[1:]]
#      58     )
# ---> 59     temp_df.columns = [
#      60         "日期",
#      61         "股票代码",
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ...

# %%
sh_list
# Out:
#         证券代码  证券简称 扩位证券简称        上市日期
# 0     600000  浦发银行   浦发银行  1999-11-10
# 1     600004  白云机场   白云机场  2003-04-28
# 2     600006  东风汽车   东风汽车  1999-07-27
# 3     600007  中国国贸   中国国贸  1999-03-12
# 4     600008  首创环保   首创环保  2000-04-27
# ...      ...   ...    ...         ...
# 1651  605580  恒盛能源   恒盛能源  2021-08-19
# 1652  605588  冠石科技   冠石科技  2021-08-12
# 1653  605589  圣泉集团   圣泉集团  2021-08-10
# 1654  605598  上海港湾   上海港湾  2021-09-17
# 1655  605599  菜百股份   菜百股份  2021-09-09
#
# [1656 rows x 4 columns]

# %%
sh_del_list = ak.stock_info_sh_delist()

# %%
sh_del_list
# Out:
#       公司代码    公司简称        上市日期      暂停上市日期
# 0   600001    邯郸钢铁  1998-01-22  2009-12-29
# 1   600002    齐鲁退市  1998-04-08  2006-04-24
# 2   600003   ST东北高  1999-08-10  2010-02-26
# 3   600005    武钢股份  1999-08-03  2017-02-14
# 4   600065  *ST联 谊  1997-05-23  2007-12-13
# ..     ...     ...         ...         ...
# 93  900935    阳晨Ｂ股  1995-07-27  2016-12-16
# 94  900949    东电Ｂ股  1997-09-23  2013-11-07
# 95  900950    新城Ｂ股  1997-10-16  2015-11-23
# 96  900951    退市大化  1997-10-21  2020-08-28
# 97  900956    东贝Ｂ股  1999-07-15  2020-11-23
#
# [98 rows x 4 columns]

# %%
stock_zh_a_hist_163_df = ak.stock_zh_a_hist_163(symbol="sh600001", start_date="20060101", end_date="20220101")

# %%
stock_zh_a_hist_163_df.to_csv("sh600001.tsv", sep="\t")

# %%
sh_list
# Out:
#         证券代码  证券简称 扩位证券简称        上市日期
# 0     600000  浦发银行   浦发银行  1999-11-10
# 1     600004  白云机场   白云机场  2003-04-28
# 2     600006  东风汽车   东风汽车  1999-07-27
# 3     600007  中国国贸   中国国贸  1999-03-12
# 4     600008  首创环保   首创环保  2000-04-27
# ...      ...   ...    ...         ...
# 1651  605580  恒盛能源   恒盛能源  2021-08-19
# 1652  605588  冠石科技   冠石科技  2021-08-12
# 1653  605589  圣泉集团   圣泉集团  2021-08-10
# 1654  605598  上海港湾   上海港湾  2021-09-17
# 1655  605599  菜百股份   菜百股份  2021-09-09
#
# [1656 rows x 4 columns]

# %%
stock_zh_index_daily_df =  ak.stock_zh_index_daily(symbol="sh000001")

# %%
stock_zh_index_daily_df
# Out:
#             date      open      high       low     close       volume
# 0     1990-12-19    96.050    99.980    95.790    99.980       126000
# 1     1990-12-20   104.300   104.390    99.980   104.390        19700
# 2     1990-12-21   109.070   109.130   103.730   109.130         2800
# 3     1990-12-24   113.570   114.550   109.130   114.550         3200
# 4     1990-12-25   120.090   120.250   114.550   120.250         1500
# ...          ...       ...       ...       ...       ...          ...
# 7714  2022-07-18  3235.088  3278.472  3226.232  3278.103  34834602200
# 7715  2022-07-19  3278.722  3283.930  3256.015  3279.431  31565191800
# 7716  2022-07-20  3291.551  3308.347  3287.744  3304.724  30151512300
# 7717  2022-07-21  3297.661  3300.535  3272.001  3272.001  33235870700
# 7718  2022-07-22  3276.197  3293.644  3246.731  3269.974  30069006600
#
# [7719 rows x 6 columns]

# %%
plt.plot(stock_zh_index_daily_df["date"], stock_zh_index_daily_df["close"])
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
stock_zh_index_5_min_df = ak.stock_zh_a_hist_min_em(symbol="000001", period="5")

# %%
stock_zh_index_5_min_df.to_csv("000001_min5_0601_0722.tsv", sep="\t")

# %%
stock_zh_index_spot_df = ak.stock_zh_index_spot()

# %%
stock_zh_index_spot_df.to_csv("zh_index.tsv", sep="\t")

# %%
stock_zh_a_hist_min_em_df = ak.stock_zh_a_hist_min_em(symbol="000001", start_date="2022-07-25 09:30:00", end_date="2022-07-25 15:00:00", period='1', adjust='')

# %%
stock_zh_a_hist_min_em_df
# Out:
#                       时间     开盘     收盘     最高     最低    成交量         成交额  \
# 0    2022-07-25 09:30:00  12.80  12.80  12.80  12.80   8775  11232000.0
# 237  2022-07-25 14:57:00  12.81  12.82  12.82  12.81   6564   8412121.0
# 238  2022-07-25 14:58:00  12.82  12.82  12.82  12.82    376    482336.0
# 239  2022-07-25 14:59:00  12.82  12.82  12.82  12.82      0         0.0
# 240  2022-07-25 15:00:00  12.82  12.82  12.82  12.82   6877   8815749.0
#
#         最新价
# 0    12.800
# 1    12.746
# 2    12.736
# 3    12.732
# 4    12.734
# ..      ...
# ...

# %%
stock_zh_a_tick_tx_js_df = ak.stock_zh_a_tick_tx_js(symbol="sz000001")
# Out:
# /usr/local/lib/python3.8/dist-packages/akshare/stock/stock_zh_a_tick_tx_163.py:28: UserWarning: 正在下载数据，请稍等
#   warnings.warn("正在下载数据，请稍等")
# /usr/local/lib/python3.8/dist-packages/akshare/stock/stock_zh_a_tick_tx_163.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df["性质"] = big_df["性质"].map(property_map)

# %%
stock_zh_a_tick_tx_js_df
# Out:
#           成交时间   成交价格  价格变动   成交量      成交金额  性质
# 0     09:25:00  12.80  0.00  8775  11232000  卖盘
# 1     09:30:00  12.77 -0.03   254    324791  卖盘
# 2     09:30:03  12.77  0.00  2675   3417127  卖盘
# 3     09:30:06  12.75 -0.02  1404   1789831  卖盘
# 4     09:30:09  12.72 -0.03   837   1064725  卖盘
# ...        ...    ...   ...   ...       ...  ..
# 4612  14:56:51  12.81  0.00  2351   3013728  卖盘
# 4613  14:56:54  12.82  0.01   104    133276  买盘
# 4614  14:56:57  12.82  0.00   145    185866  买盘
# 4615  14:57:00  12.82  0.00   376    482336  买盘
# 4616  15:00:03  12.82  0.00  6877   8815750  卖盘
#
# [4617 rows x 6 columns]

# %%
index_zh_a_hist_min_em_df = ak.index_zh_a_hist_min_em(symbol="000001", period="1", start_date="2022-06-25 09:30:00", end_date="2222-01-01 09:32:00")

# %%
index_zh_a_hist_min_em_df
# Out:
#                        时间       开盘       收盘       最高       最低      成交量  \
# 0     2022-07-19 09:30:00     0.00  3278.72  3278.72  3278.72  2554500
# 1     2022-07-19 09:31:00     0.00  3269.96  3278.10  3269.24  7905650
# 2     2022-07-19 09:32:00     0.00  3271.29  3271.47  3269.41  4927290
# 3     2022-07-19 09:33:00     0.00  3275.20  3275.37  3271.39  4842815
# 4     2022-07-19 09:34:00     0.00  3275.34  3276.66  3274.48  4992506
# ...                   ...      ...      ...      ...      ...      ...
# 1200  2022-07-25 14:56:00  3251.13  3250.94  3251.45  3250.55  1577668
# 1201  2022-07-25 14:57:00  3250.88  3250.76  3251.48  3250.66  1727876
# 1202  2022-07-25 14:58:00  3251.11  3250.98  3251.11  3250.75   119875
# 1203  2022-07-25 14:59:00  3250.98  3250.98  3250.98  3250.98        0
# 1204  2022-07-25 15:00:00  3250.98  3250.39  3251.27  3250.39  2902486
#
#                成交额       最新价
# 0     2.449044e+09  3284.002
# 1     8.568229e+09  3276.605
# ...
