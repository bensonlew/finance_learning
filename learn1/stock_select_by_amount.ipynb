# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import akshare as ak
import datetime
import numpy as np

# %%
import pymongo

uri = 'mongodb://localhost:27017'

client = pymongo.MongoClient(uri)
coll = client.quantaxis.stock_min

# %%
def find2mongo2df():
    records = coll.find({"time_stamp" : 1632274500.0})
    return pd.DataFrame(list(records))

# %%
stock_df = find2mongo2df()

# %%
coll = client.quantaxis.stock_min
# Out:
#                            _id    open   close    high     low         vol  \
# 0     647203dd5cba8b728a0b617c   17.87   17.72   17.87   17.42  21526100.0
# 1     647203e1e8a494494ebe5db1   18.90   18.96   18.96   18.74   9830800.0
# 2     647203e503e1385489f0e357   18.78   18.89   19.04   18.65    355800.0
# 3     647203ea629ffe101468e122    2.24    2.24    2.24    2.19   1446500.0
# 4     647203ee70ebcc078d4d9615    4.46    4.49    4.51    4.45    941100.0
# ...                        ...     ...     ...     ...     ...         ...
# 4417  64729c4f687405b0919c0b0d  223.00  222.28  223.00  222.02      9100.0
# 4418  64729c50687405b0919c5f6d   40.06   40.12   40.25   39.80     53500.0
# 4420  64729c54687405b0919d079d   44.00   44.58   44.64   43.60    217200.0
# 4421  64729c56687405b0919d5bfd   55.10   55.18   55.42   55.05   1435500.0
# 4422  64729c58687405b0919db05d   80.00   80.88   81.00   79.21     34600.0
#
# ...

# %%
from QUANTAXIS.QAFetch.QAQuery import QA_fetch_etf_min, QA_fetch_stock_min
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from QUANTAXIS.QAFetch.QAQuery import QA_fetch_etf_min, QA_fetch_stock_min
#
# ImportError: cannot import name 'QA_fetch_etf_min' from 'QUANTAXIS.QAFetch.QAQuery' (/liubinxu/liubinxu/miniconda3/lib/python3.10/site-packages/QUANTAXIS/QAFetch/QAQuery.py)

# %%
df = QA_fetch_stock_min("000001", "2010-01-01", "2030-01-01", format="pd")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = QA_fetch_stock_min("000001", "2010-01-01", "2030-01-01", format="pd")
#
# NameError: name 'QA_fetch_stock_min' is not defined
